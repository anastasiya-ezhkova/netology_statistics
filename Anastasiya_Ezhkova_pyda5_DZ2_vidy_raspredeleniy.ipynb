# %% [markdown]
# # Виды распределений

# %% [markdown]
# #### 1. Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns
import statistics

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
url='http://yustiks.ru/housing.csv'
s=requests.get(url).content
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(io.StringIO(s.decode('utf-8')),  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %%
#Частотный график для CRIM
plt.hist(data['CRIM'], len(data))
plt.xlabel('CRIM')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# Данный график плотности распределения похож на Логнормальное распределение (так как значение CRIM может принимать неопределенное кол-во значений, т.е., это непрерывное распределение)

# %%
#Частотный график для ZN
plt.hist(data['ZN'], len(data))
plt.xlabel('ZN')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# Данный график плотности распределения больше похож на Геометрическое распределение

# %%
#Частотный график для INDUS
plt.hist(data['INDUS'], len(data))
plt.xlabel('INDUS')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# График INDUS похож на Биномиальное распределение

# %%
#Частотный график для CHAS
plt.hist(data['CHAS'], len(data))
plt.xlabel('CHAS')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# Это распределение является распределением Бернулли, так как данные могут принимать всего два значения: 0 и 1

# %%
#Частотный график для NOX
plt.hist(data['NOX'], len(data))
plt.xlabel('NOX')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# Это график непрерывного распределения, но к какому-то конкретному виду отнести его сложно

# %%
#Частотный график для RM
plt.hist(data['RM'], len(data))
plt.xlabel('RM')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# Это график нормального распределения

# %%
#Частотный график для AGE
plt.hist(data['AGE'], len(data))
plt.xlabel('AGE')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# Этот график похож на Биномиальное распределение или на Юниформ распределение

# %%
#Частотный график для DIS
plt.hist(data['DIS'], len(data))
plt.xlabel('DIS')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# Этот график похож на непрерывное Гамма-распределение

# %%
#Частотный график для RAD
plt.hist(data['RAD'], len(data))
plt.xlabel('RAD')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# Это Биномиальное распределение

# %%
#Частотный график для TAX
plt.hist(data['TAX'], len(data))
plt.xlabel('TAX')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# Это Геометрическое распределение

# %%
#Частотный график для PTRATIO
plt.hist(data['PTRATIO'], len(data))
plt.xlabel('PTRATIO')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# Это Биномиальное распределение

# %%
#Частотный график для B
plt.hist(data['B'], len(data))
plt.xlabel('B')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# Это Геометрическое распределение

# %%
#Частотный график для LSTAT
plt.hist(data['LSTAT'], len(data))
plt.xlabel('LSTAT')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# Этот график похож на Негативное Биномиальное распределение

# %%
#Частотный график для MEDV
plt.hist(data['MEDV'], len(data))
plt.xlabel('MEDV')
plt.ylabel('Количество встречаемости значения')
plt.show()

# %% [markdown]
# Это Нормальное распределение с выбросом

# %% [markdown]
# #### 2. Загрузить таблицу Happiness report. Нарисовать матрицу ковариаций попарно.

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data=pd.read_csv(url)
data.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %% [markdown]
# #### 3. Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop). Написать код.

# %%
print("Количество отсутствующих значений в таблице по всем столбцам:", sum(data.isnull().sum()))
# Out:
# Количество отсутствующих значений в таблице по всем столбцам: 23

# %%
#Уберем все отсутствующие значения
data1 = data.dropna()

# %%
#Проверим, что отсутствующих значений в выборке теперь нет
sum(data1.isnull().sum())
# Out:
# 0

# %%
#Посмотрим, насколько сократилось количество строк в таблице
print("Раньше в таблице было", len(data), "строк, а теперь -", len(data1))
# Out:
# Раньше в таблице было 156 строк, а теперь - 140

# %%
#Посчитаем матрицу ковариаций попарно и построим график для 8ми показателей таблицы
X = data1.iloc[:,3:11]
X.head()
# Out:
#    Positive affect  Negative affect  Social support  Freedom  Corruption  \
# 0             41.0             10.0             2.0      5.0         4.0
# 1             24.0             26.0             4.0      6.0         3.0
# 2             16.0             29.0             3.0      3.0         8.0
# 3              3.0              3.0             1.0      7.0        45.0
# 4             12.0             25.0            15.0     19.0        12.0
#
#    Generosity  Log of GDP\nper capita  Healthy life\nexpectancy
# 0        47.0                    22.0                      27.0
# 1        22.0                    14.0                      23.0
# 2        11.0                     7.0                      12.0
# 3         3.0                    15.0                      13.0
# 4         7.0                    12.0                      18.0

# %%
np.around(np.cov(X.T), decimals=1)
# Out:
# array([[1965.3,  694.3,  880.1, 1393. ,  427.2,  827. ,  597.5,  661. ],
#        [ 694.3, 1980.8, 1369. ,  835. ,  316. ,  697.8, 1091.7,  992.7],
#        [ 880.1, 1369. , 2099.1,  989.2,  291. ,  918.3, 1592.9, 1521.9],
#        [1393. ,  835. ,  989.2, 2034.8,  784.2, 1005.2,  754.8,  841.1],
#        [ 427.2,  316. ,  291. ,  784.2, 1819.5,  536.4,  344.2,  279.5],
#        [ 827. ,  697.8,  918.3, 1005.2,  536.4, 2000.6,  891.6,  891.4],
#        [ 597.5, 1091.7, 1592.9,  754.8,  344.2,  891.6, 1879.8, 1665.8],
#        [ 661. ,  992.7, 1521.9,  841.1,  279.5,  891.4, 1665.8, 1934.2]])

# %%
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(X)

# %% [markdown]
# **Вывод**: из попарного сравнения показателей можно обнаружить положительную линейную зависимость между парами Social support и Log of GDP per capita, Healthy life expectancy и Log of GDP per capita

# %% [markdown]
# #### 4. Сколько стран в выборке? Написать ответ. Можно ли сказать, что данные значения - это **проблема классификации**?

# %%
print("Количество стран в очищенной от отсутствующих значений выборке:", len(data1['Country (region)']))
# Out:
# Количество стран в очищенной от отсутствующих значений выборке: 140

# %% [markdown]
# Я считаю, что данные значения можно рассмотреть как проблему классификации, и ниже это продемонстрировано на графике

# %% [markdown]
# #### 5. Нарисовать sns.pairplot для класс - страна. Из графика сделать вывод о том, какие страны похожи.

# %%
X2 = data1.iloc[:,:11]
X2.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
sns.set(style="ticks", color_codes=True)
fig = sns.pairplot(data=X2, hue='Country (region)')
plt.show()

# %% [markdown]
# **Вывод**: из классификации видно, что на большинстве графиков развитые страны (такие, например, как Канада, Финляндия, Австралия, новая Зеландия, Швеция) находятся в левой нижней части графика, тогда как развивающиеся и бедные страны (Танзания, Йемен, Руанда, Ботсвана) - в правой верхней. Таким образом, можно классифицировать данные по группам в соответствии с уровнем развитости стран (их экономике, уровню ВВП на душу населения и т.д.)

# %% [markdown]
# #### 6. Посчитать матрицу корреляций для таблицы. Написать код. Сделать график. Какие можно сделать выводы?

# %%
data1.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
print('Корреляционная матрица')
np.around(data1.corr(), decimals=2)
# Out:
# Корреляционная матрица
#                           Ladder  SD of Ladder  Positive affect  \
# Ladder                      1.00          0.56             0.51
# SD of Ladder                0.56          1.00             0.09
# Positive affect             0.51          0.09             1.00
# Negative affect             0.54          0.63             0.35
# Social support              0.83          0.60             0.43
# Freedom                     0.55          0.25             0.70
# Corruption                  0.22          0.25             0.23
# Generosity                  0.49          0.39             0.42
# Log of GDP\nper capita      0.82          0.66             0.31
# Healthy life\nexpectancy    0.83          0.64             0.34
#
#                           Negative affect  Social support  Freedom  \
# Ladder                               0.54            0.83     0.55
# SD of Ladder                         0.63            0.60     0.25
# ...

# %%
import seaborn as sns
sns.heatmap(data1.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.show()

# %% [markdown]
# **Вывод**: как и в графике ковариации, на этом графике видна сильная взаимосвязь между показателями Social support и Log of GDP per capita, Healthy life expectancy и Log of GDP per capita. Кроме того, можно сделать вывод, что целевой показатель данной таблицы, уровень удовлетворенности (Ladder), зависит по большей части от таких показателей, как Social support, Log of GDP per capita и Healthy life expectancy. Positive и Negative affect в равной мере не оказывают достаточно сильного влияния на целевой показатель.

# %% [markdown]
# 7. **Регрессионный анализ** - можно ли провести линейную зависимость между двумя выборками. Возьмем Ladder - удовлетворение жизнью, и generosity - доброта. Мы хотим найти прямую, которая разделит точки в пространстве наполовину. Это можно сделать графически. Нарисовать график. Можно ли сказать, что данная прямая является собственным вектором? При проецировании данных на эту прямую разброс данных максимален?

# %%
sns.regplot(x = data1['Ladder'], y = data1['Generosity'], data=data1, fit_reg=True)
plt.xlabel('Уровень удовлетворенности в стране')
plt.ylabel('Уровень доброты/щедрости в стране')
plt.title('Корреляционная зависимость двух выборок')
plt.grid(False)
plt.show()

# %% [markdown]
# Полученная прямая не является собственным вектором, так как на графике показана линейная регрессия, то есть прямая, сумма расстояний от каждого элемента до которой минимальна. График демонстрирует зависимость двух переменных - чем выше уровень доброты/щедрости в стране (Generosity), тем выше уровень удовлетворенности (Ladder).

# %% [markdown]
# #### 8. Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
# кол-во испытаний
trials = 10


values = np.random.randint(1, 7, size=trials)
plt.hist(values, bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5])
plt.xlabel('Значение кубика')
plt.ylabel('Количество раз')
plt.title('Подбрасывание кубика 10 раз')
plt.show()

# %% [markdown]
# Напишите код для моделирования 1000 подбрасываний игрального кубика. Начертите диаграму histogram. Почему график изменился? Как применить центральную предельную теорему?

# %%
# кол-во испытаний
trials = 1000


values = np.random.randint(1, 7, size=trials)
plt.hist(values, bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5])
plt.xlabel('Значение кубика')
plt.ylabel('Количество раз')
plt.title('Подбрасывание кубика 1000 раз')
plt.show()

# %% [markdown]
# Центральная предельная теорема говорит о том, что при большом числе опытов любое распределение стремится к нормальному. Но на графике мне это продемонстрировать не удалось.
